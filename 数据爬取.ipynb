# %%
#######################################
#      The generated by curl2py.      
#      author：小小明                  
#######################################

import requests
import json
import pandas as pd
import os
import time
import random

allData = []

headers = {
    "authority": "xxkol.cn",
    "sec-ch-ua": "\" Not A;Brand\";v=\"99\", \"Chromium\";v=\"96\", \"Microsoft Edge\";v=\"96\"",
    "accept": "application/json, text/plain, */*",
    "dnt": "1",
    "authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyaW5mbyI6eyJvcGVuaWQiOiJvcEowYzBncThuQmV1djgtRnV3NDBaaHdjNTVrIiwiaWQiOjE2MzkxfSwiaXNzIjoiaHR0cHM6XC9cL2JhY2sueHhrb2wuY24iLCJhdWQiOiJodHRwczpcL1wvYmFjay54eGtvbC5jbiIsImlhdCI6MTY0MDg1MzgyMiwibmJmIjoxNjQwODUzODIyLCJleHAiOjE2NDE0NTg2MjJ9._JEIhLQWhuJbqyyiRZZcLbpIeL8xtMj7aDiWzmtK4Ek",
    "sec-ch-ua-mobile": "?0",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36 Edg/96.0.1054.62",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-site": "same-origin",
    "sec-fetch-mode": "cors",
    "sec-fetch-dest": "empty",
    "referer": "https://xxkol.cn/rank/kol/follower",
    "accept-language": "zh-CN,zh;q=0.9,en-GB;q=0.8,en;q=0.7,en-US;q=0.6"
}
cookies = {
    "xxtoken": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyaW5mbyI6eyJvcGVuaWQiOiJvcEowYzBncThuQmV1djgtRnV3NDBaaHdjNTVrIiwiaWQiOjE2MzkxfSwiaXNzIjoiaHR0cHM6XC9cL2JhY2sueHhrb2wuY24iLCJhdWQiOiJodHRwczpcL1wvYmFjay54eGtvbC5jbiIsImlhdCI6MTY0MDg1MzgyMiwibmJmIjoxNjQwODUzODIyLCJleHAiOjE2NDE0NTg2MjJ9._JEIhLQWhuJbqyyiRZZcLbpIeL8xtMj7aDiWzmtK4Ek",
    "Hm_lvt_d4217dc2524e360ff487588dd84ad4ab": "1640853528,1640853871",
    "Hm_lpvt_d4217dc2524e360ff487588dd84ad4ab": "1640853871"
}
params = {
    "pagesize": "100", # 10万条，就是1000次查询
    "page": "1",
    "attribute": "",
    "category": "",
    "sort_type": "follower"
}

for i in range(1, 11):
    print('fetching... %d' % i)
    params["page"] = str(i)
    res = requests.get(
        "https://xxkol.cn/api/range/bili",
        params=params,
        headers=headers,
        cookies=cookies
    )
    allData.extend(res.json()['data']['data'])
    ran = 2 + round(random.random()*10%3)
    time.sleep(ran)
    
# print(res.text)



df = pd.DataFrame(allData)
#df

file = "b站up主粉丝量top10万.csv"
df.to_csv(file, index=False, mode='a', header=not os.path.exists(file), encoding="u8")
# Out:
# fetching... 1
# fetching... 2
# fetching... 3
# fetching... 4
# fetching... 5
# fetching... 6
# fetching... 7
# fetching... 8
# fetching... 9
# fetching... 10

# %%
import pandas as pd

names =  ["名称", "性别", "签名", "视频数量","粉丝数",
         "播放数", "点赞数", "总充电人数", "月充电人数",
         "生日", "category1", "category2", "tags"]

df = pd.read_csv("b站up主粉丝量top10万.csv", usecols=[2,3,5]+list(range(9,16))+[22,23,24], header=0, names=names, low_memory=False)
df.drop_duplicates(inplace=True)
df.sort_values("粉丝数", ascending=False, inplace=True)

df
# Out:
#           名称  性别                                                 签名   视频数量  \
# 810      郝给力  保密                                     做最给力的自己！拔出你的剑！  205.0
# 811     冰糖IO   女  既是UP主也是虚拟主播，同时还是3D动画师。目标是成为你的快乐源泉(•ㅂ•)~！做的视频类型...  910.0
# 812    米国脱口秀   女                        热爱脱口秀文化，商业合作请私信。译文或转载国外脱口秀。  353.0
# 813    大聪看电影   男          过度解读&开脑洞，商务合作：170025343@qq.com（请简单说明合作内容）  379.0
# 814    天下一场梦  保密  不参与任何动物买卖，不提供任何买卖渠道，不养违法动物，偶尔捡到的野鸟都会放生，关爱小动物从我做起。  860.0
# ..       ...  ..                                                ...    ...
# 807    伦桑爱唱歌   男                 唱给懂的人听~ 合作WX：Paor_0222(请注明来意，否则不加)  231.0
# 808      甘子七  保密               1998届全国海王大赛第三名商务合作+Vx13910851252备注大甘  224.0
# 809  哔哩哔哩直播姬  保密              娱乐、电台、学习分区官号，独乐乐不如众乐乐 QQ群：1055222626。  354.0
# 578        1   0                                            1280863   10.0
# 577       山新   女                                     都说了是天依爹地，不是妈咪。    NaN
#
# ...

# %%
df = df[~df.名称.str.contains('哔哩哔哩')]
df.shape[0]
# Out:
# 982

# %%
df = df.query("粉丝数>=10000")
df.shape[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1599/1835791388.py in <module>
# ----> 1 df=df.query("粉丝数>=10000")
#       2 df.shape[0]
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4058         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4059         kwargs["target"] = None
# -> 4060         res = self.eval(expr, **kwargs)
#    4061
#    4062         try:
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4189         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    4190
# -> 4191         return _eval(expr, inplace=inplace, **kwargs)
#    4192
#    4193     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# ...
